# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import warnings
warnings.filterwarnings('ignore')


import pylab as plt
import seaborn as sns

from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

from selenium.webdriver.common.by import By   # para buscar segun tag, id, class, etc...
from selenium import webdriver
import time

from selenium import webdriver
from tqdm import tqdm

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
PATH=ChromeDriverManager().install()

# %%
url = 'https://www.nba.com/stats/players/traditional?dir=A&sort=PTS&Season=2021-22'

# %%
driver=webdriver.Chrome(PATH)

driver.get(url)

# %%
driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]').click() #acepto cookies

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla = driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 605/605 [04:44<00:00,  2.13it/s]
# ['1',
#  'Joel Embiid',
#  'PHI',
#  '28',
#  '68',
#  '45',
#  '23',
#  '33.8',
#  '30.6',
#  '9.8',
#  '19.6',
#  '49.9',
#  '1.4',
#  '3.7',
#  '37.1',
#  '9.6',
#  '11.8',
#  '81.4',
#  '2.1',
#  '9.6',
#  '11.7',
#  '4.2',
#  '3.1',
#  '1.1',
#  '1.5',
#  '2.7',
#  '55.5',
#  '46.0',
#  '2.0',
#  '5.4']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2021_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2021_seasons_stats.head()
# Out:
#                      PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA  \
# 0  1            Joel Embiid  PHI  28  68  45  23  33.8  30.6   9.8  19.6
# 1  2           LeBron James  LAL  37  56  25  31  37.2  30.3  11.4  21.8
# 2  3  Giannis Antetokounmpo  MIL  27  67  45  22  32.9  29.9  10.3  18.6
# 3  4           Kevin Durant  BKN  33  55  36  19  37.2  29.9  10.5  20.3
# 4  5            Luka Doncic  DAL  23  65  44  21  35.4  28.4   9.9  21.6
#
#     FG%  3PM  3PA   3P%  FTM   FTA   FT% OREB DREB   REB  AST  TOV  STL  BLK  \
# 0  49.9  1.4  3.7  37.1  9.6  11.8  81.4  2.1  9.6  11.7  4.2  3.1  1.1  1.5
# 1  52.4  2.9  8.0  35.9  4.5   6.0  75.6  1.1  7.1   8.2  6.2  3.5  1.3  1.1
# 2  55.3  1.1  3.6  29.3  8.3  11.4  72.2  2.0  9.6  11.6  5.8  3.3  1.1  1.4
# 3  51.8  2.1  5.5  38.3  6.8   7.4  91.0  0.5  6.9   7.4  6.4  3.5  0.9  0.9
# 4  45.7  3.1  8.8  35.3  5.6   7.5  74.4  0.9  8.3   9.1  8.7  4.5  1.2  0.6
#
#     PF    FP   DD2   TD3   +/-
# 0  2.7  55.5  46.0   2.0   5.4
# ...

# %%
df_2021_seasons_stats['SEASON'] = '2022'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[3]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 540/540 [04:19<00:00,  2.08it/s]
# ['1',
#  'Stephen Curry',
#  'GSW',
#  '33',
#  '63',
#  '37',
#  '26',
#  '34.2',
#  '32.0',
#  '10.4',
#  '21.7',
#  '48.2',
#  '5.3',
#  '12.7',
#  '42.1',
#  '5.7',
#  '6.3',
#  '91.6',
#  '0.5',
#  '5.0',
#  '5.5',
#  '5.8',
#  '3.4',
#  '1.2',
#  '0.1',
#  '1.9',
#  '47.9',
#  '8.0',
#  '0.0',
#  '3.9']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2020_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2020_seasons_stats.head()
# Out:
#                      PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA  \
# 0  1          Stephen Curry  GSW  33  63  37  26  34.2  32.0  10.4  21.7
# 1  2           Bradley Beal  WAS  28  60  32  28  35.8  31.3  11.2  23.0
# 2  3         Damian Lillard  POR  30  67  39  28  35.8  28.8   9.0  19.9
# 3  4            Joel Embiid  PHI  27  51  39  12  31.1  28.5   9.0  17.6
# 4  5  Giannis Antetokounmpo  MIL  26  61  40  21  33.0  28.1  10.3  18.0
#
#     FG%  3PM   3PA   3P%  FTM   FTA   FT% OREB DREB   REB  AST  TOV  STL  BLK  \
# 0  48.2  5.3  12.7  42.1  5.7   6.3  91.6  0.5  5.0   5.5  5.8  3.4  1.2  0.1
# 1  48.5  2.2   6.2  34.9  6.8   7.7  88.9  1.2  3.5   4.7  4.4  3.1  1.2  0.4
# 2  45.1  4.1  10.5  39.1  6.7   7.2  92.8  0.5  3.7   4.2  7.5  3.0  0.9  0.3
# 3  51.3  1.1   3.0  37.7  9.2  10.7  85.9  2.2  8.4  10.6  2.8  3.1  1.0  1.4
# 4  56.9  1.1   3.6  30.3  6.5   9.5  68.5  1.6  9.4  11.0  5.9  3.4  1.2  1.2
#
#     PF    FP   DD2  TD3   +/-
# ...

# %%
df_2020_seasons_stats['SEASON'] = '2021'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[4]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 529/529 [04:37<00:00,  1.91it/s]
# ['1',
#  'James Harden',
#  'HOU',
#  '30',
#  '68',
#  '43',
#  '25',
#  '36.5',
#  '34.3',
#  '9.9',
#  '22.3',
#  '44.4',
#  '4.4',
#  '12.4',
#  '35.5',
#  '10.2',
#  '11.8',
#  '86.5',
#  '1.0',
#  '5.5',
#  '6.6',
#  '7.5',
#  '4.5',
#  '1.8',
#  '0.9',
#  '3.3',
#  '57.1',
#  '22.0',
#  '4.0',
#  '4.2']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2019_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2019_seasons_stats.head()
# Out:
#                      PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA  \
# 0  1           James Harden  HOU  30  68  43  25  36.5  34.3   9.9  22.3
# 1  2           Bradley Beal  WAS  27  57  20  37  36.0  30.5  10.4  22.9
# 2  3         Damian Lillard  POR  29  66  33  33  37.5  30.0   9.5  20.4
# 3  4             Trae Young  ATL  21  60  18  42  35.3  29.6   9.1  20.8
# 4  5  Giannis Antetokounmpo  MIL  25  63  51  12  30.4  29.5  10.9  19.7
#
#     FG%  3PM   3PA   3P%   FTM   FTA   FT% OREB  DREB   REB  AST  TOV  STL  \
# 0  44.4  4.4  12.4  35.5  10.2  11.8  86.5  1.0   5.5   6.6  7.5  4.5  1.8
# 1  45.5  3.0   8.4  35.3   6.8   8.0  84.2  0.9   3.3   4.2  6.1  3.4  1.2
# 2  46.3  4.1  10.2  40.1   7.0   7.8  88.8  0.5   3.8   4.3  8.0  2.9  1.1
# 3  43.7  3.4   9.5  36.1   8.0   9.3  86.0  0.5   3.7   4.3  9.3  4.8  1.1
# 4  55.3  1.4   4.7  30.4   6.3  10.0  63.3  2.2  11.4  13.6  5.6  3.7  1.0
#
#    BLK   PF    FP   DD2  TD3   +/-
# 0  0.9  3.3  57.1  22.0  4.0   4.2
# ...

# %%
df_2019_seasons_stats['SEASON'] = '2020'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[5]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 530/530 [05:40<00:00,  1.56it/s]
# ['1',
#  'James Harden',
#  'HOU',
#  '29',
#  '78',
#  '51',
#  '27',
#  '36.8',
#  '36.1',
#  '10.8',
#  '24.5',
#  '44.2',
#  '4.8',
#  '13.2',
#  '36.8',
#  '9.7',
#  '11.0',
#  '87.9',
#  '0.8',
#  '5.8',
#  '6.6',
#  '7.5',
#  '5.0',
#  '2.0',
#  '0.7',
#  '3.1',
#  '58.7',
#  '34.0',
#  '7.0',
#  '4.6']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2018_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2018_seasons_stats.head()
# Out:
#                      PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA  \
# 0  1           James Harden  HOU  29  78  51  27  36.8  36.1  10.8  24.5
# 1  2            Paul George  OKC  29  77  46  31  36.9  28.0   9.2  21.0
# 2  3  Giannis Antetokounmpo  MIL  24  72  56  16  32.8  27.7  10.0  17.3
# 3  4            Joel Embiid  PHI  25  64  43  21  33.7  27.5   9.1  18.7
# 4  5           LeBron James  LAL  34  55  28  27  35.2  27.4  10.1  19.9
#
#     FG%  3PM   3PA   3P%  FTM   FTA   FT% OREB  DREB   REB  AST  TOV  STL  \
# 0  44.2  4.8  13.2  36.8  9.7  11.0  87.9  0.8   5.8   6.6  7.5  5.0  2.0
# 1  43.8  3.8   9.8  38.6  5.9   7.0  83.9  1.4   6.8   8.2  4.1  2.7  2.2
# 2  57.8  0.7   2.8  25.6  6.9   9.5  72.9  2.2  10.3  12.5  5.9  3.7  1.3
# 3  48.4  1.2   4.1  30.0  8.2  10.1  80.4  2.5  11.1  13.6  3.7  3.5  0.7
# 4  51.0  2.0   5.9  33.9  5.1   7.6  66.5  1.0   7.4   8.5  8.3  3.6  1.3
#
#    BLK   PF    FP   DD2  TD3  +/-
# 0  0.7  3.1  58.7  34.0  7.0  4.6
# ...

# %%
df_2018_seasons_stats['SEASON'] = '2019'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[6]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 540/540 [06:27<00:00,  1.39it/s]
# ['1',
#  'James Harden',
#  'HOU',
#  '28',
#  '72',
#  '59',
#  '13',
#  '35.4',
#  '30.4',
#  '9.0',
#  '20.1',
#  '44.9',
#  '3.7',
#  '10.0',
#  '36.7',
#  '8.7',
#  '10.1',
#  '85.8',
#  '0.6',
#  '4.8',
#  '5.4',
#  '8.8',
#  '4.4',
#  '1.8',
#  '0.7',
#  '2.3',
#  '53.0',
#  '31.0',
#  '4.0',
#  '7.3']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2017_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2017_seasons_stats.head()
# Out:
#                      PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA  \
# 0  1           James Harden  HOU  28  72  59  13  35.4  30.4   9.0  20.1
# 1  2          Anthony Davis  NOP  25  75  45  30  36.4  28.1  10.4  19.5
# 2  3           LeBron James  CLE  33  82  50  32  36.9  27.5  10.5  19.3
# 3  4         Damian Lillard  POR  27  73  44  29  36.6  26.9   8.5  19.4
# 4  5  Giannis Antetokounmpo  MIL  23  75  39  36  36.7  26.9   9.9  18.7
#
#     FG%  3PM   3PA   3P%  FTM   FTA   FT% OREB DREB   REB  AST  TOV  STL  BLK  \
# 0  44.9  3.7  10.0  36.7  8.7  10.1  85.8  0.6  4.8   5.4  8.8  4.4  1.8  0.7
# 1  53.4  0.7   2.2  34.0  6.6   8.0  82.8  2.5  8.6  11.1  2.3  2.2  1.5  2.6
# 2  54.2  1.8   5.0  36.7  4.7   6.5  73.1  1.2  7.5   8.6  9.1  4.2  1.4  0.9
# 3  43.9  3.1   8.6  36.1  6.8   7.4  91.6  0.8  3.6   4.5  6.6  2.8  1.1  0.4
# 4  52.9  0.6   1.9  30.7  6.5   8.5  76.0  2.1  8.0  10.0  4.8  3.0  1.5  1.4
#
#     PF    FP   DD2   TD3  +/-
# ...

# %%
df_2017_seasons_stats['SEASON'] = '2018'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[7]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 486/486 [06:34<00:00,  1.23it/s]
# ['1',
#  'Russell Westbrook',
#  'OKC',
#  '28',
#  '81',
#  '46',
#  '35',
#  '34.6',
#  '31.6',
#  '10.2',
#  '24.0',
#  '42.5',
#  '2.5',
#  '7.2',
#  '34.3',
#  '8.8',
#  '10.4',
#  '84.5',
#  '1.7',
#  '9.0',
#  '10.7',
#  '10.4',
#  '5.4',
#  '1.6',
#  '0.4',
#  '2.3',
#  '60.6',
#  '62.0',
#  '42.0',
#  '3.1']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2016_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2016_seasons_stats.head()
# Out:
#                  PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA   FG%  \
# 0  1  Russell Westbrook  OKC  28  81  46  35  34.6  31.6  10.2  24.0  42.5
# 1  2       James Harden  HOU  27  81  54  27  36.4  29.1   8.3  18.9  44.0
# 2  3      Isaiah Thomas  BOS  28  76  51  25  33.8  28.9   9.0  19.4  46.3
# 3  4      Anthony Davis  NOP  24  75  31  44  36.1  28.0  10.3  20.3  50.5
# 4  5      DeMar DeRozan  TOR  27  74  47  27  35.4  27.3   9.7  20.9  46.7
#
#    3PM  3PA   3P%  FTM   FTA   FT% OREB DREB   REB   AST  TOV  STL  BLK   PF  \
# 0  2.5  7.2  34.3  8.8  10.4  84.5  1.7  9.0  10.7  10.4  5.4  1.6  0.4  2.3
# 1  3.2  9.3  34.7  9.2  10.9  84.7  1.2  7.0   8.1  11.2  5.7  1.5  0.5  2.7
# 2  3.2  8.5  37.9  7.8   8.5  90.9  0.6  2.1   2.7   5.9  2.8  0.9  0.2  2.2
# 3  0.5  1.8  29.9  6.9   8.6  80.2  2.3  9.5  11.8   2.1  2.4  1.3  2.2  2.2
# 4  0.4  1.7  26.6  7.4   8.7  84.2  0.9  4.3   5.2   3.9  2.4  1.1  0.2  1.8
#
#      FP   DD2   TD3  +/-
# 0  60.6  62.0  42.0  3.1
# ...

# %%
df_2016_seasons_stats['SEASON'] = '2017'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[8]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 476/476 [07:49<00:00,  1.01it/s]
# ['1',
#  'Stephen Curry',
#  'GSW',
#  '28',
#  '79',
#  '71',
#  '8',
#  '34.2',
#  '30.1',
#  '10.2',
#  '20.2',
#  '50.4',
#  '5.1',
#  '11.2',
#  '45.4',
#  '4.6',
#  '5.1',
#  '90.8',
#  '0.9',
#  '4.6',
#  '5.4',
#  '6.7',
#  '3.3',
#  '2.1',
#  '0.2',
#  '2.0',
#  '50.3',
#  '15.0',
#  '2.0',
#  '12.9']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2015_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2015_seasons_stats.head()
# Out:
#                 PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA   FG%  \
# 0  1     Stephen Curry  GSW  28  79  71   8  34.2  30.1  10.2  20.2  50.4
# 1  2      James Harden  HOU  26  82  41  41  38.1  29.0   8.7  19.7  43.9
# 2  3      Kevin Durant  OKC  27  72  52  20  35.8  28.2   9.7  19.2  50.5
# 3  4  DeMarcus Cousins  SAC  25  65  29  36  34.6  26.9   9.2  20.5  45.1
# 4  5      LeBron James  CLE  31  76  56  20  35.6  25.3   9.7  18.6  52.0
#
#    3PM   3PA   3P%  FTM   FTA   FT% OREB DREB   REB  AST  TOV  STL  BLK   PF  \
# 0  5.1  11.2  45.4  4.6   5.1  90.8  0.9  4.6   5.4  6.7  3.3  2.1  0.2  2.0
# 1  2.9   8.0  35.9  8.8  10.2  86.0  0.8  5.3   6.1  7.5  4.6  1.7  0.6  2.8
# 2  2.6   6.7  38.7  6.2   6.9  89.8  0.6  7.6   8.2  5.0  3.5  1.0  1.2  1.9
# 3  1.1   3.2  33.3  7.3  10.2  71.8  2.4  9.1  11.5  3.3  3.8  1.6  1.4  3.6
# 4  1.1   3.7  30.9  4.7   6.5  73.1  1.5  6.0   7.4  6.8  3.3  1.4  0.6  1.9
#
#      FP   DD2  TD3   +/-
# 0  50.3  15.0  2.0  12.9
# ...

# %%
df_2015_seasons_stats['SEASON'] = '2016'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[9]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tabla.find_elements(By.TAG_NAME, 'tr')]

teams[0]
# Out:
# ['1',
#  'Russell Westbrook',
#  'OKC',
#  '26',
#  '67',
#  '40',
#  '27',
#  '34.4',
#  '28.1',
#  '9.4',
#  '22.0',
#  '42.6',
#  '1.3',
#  '4.3',
#  '29.9',
#  '8.1',
#  '9.8',
#  '83.5',
#  '1.9',
#  '5.4',
#  '7.3',
#  '8.6',
#  '4.4',
#  '2.1',
#  '0.2',
#  '2.7',
#  '52.3',
#  '31.0',
#  '11.0',
#  '3.7']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2014_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2014_seasons_stats.head()
# Out:
#                  PLAYER TEAM AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  \
# 0  1  Russell Westbrook  OKC  26  67  40  27  34.4  28.1  9.4  22.0  42.6
# 1  2       James Harden  HOU  25  81  56  25  36.8  27.4  8.0  18.1  44.0
# 2  3       Kevin Durant  OKC  26  27  18   9  33.8  25.4  8.8  17.3  51.0
# 3  4       LeBron James  CLE  30  69  50  19  36.1  25.3  9.0  18.5  48.8
# 4  5      Anthony Davis  NOP  22  68  39  29  36.1  24.4  9.4  17.6  53.5
#
#    3PM  3PA   3P%  FTM   FTA   FT% OREB DREB   REB  AST  TOV  STL  BLK   PF  \
# 0  1.3  4.3  29.9  8.1   9.8  83.5  1.9  5.4   7.3  8.6  4.4  2.1  0.2  2.7
# 1  2.6  6.9  37.5  8.8  10.2  86.8  0.9  4.7   5.7  7.0  4.0  1.9  0.7  2.6
# 2  2.4  5.9  40.3  5.4   6.3  85.4  0.6  6.0   6.6  4.1  2.7  0.9  0.9  1.5
# 3  1.7  4.9  35.4  5.4   7.7  71.0  0.7  5.3   6.0  7.4  3.9  1.6  0.7  2.0
# 4  0.0  0.2   8.3  5.5   6.8  80.5  2.5  7.7  10.2  2.2  1.4  1.5  2.9  2.1
#
#      FP   DD2   TD3  +/-
# 0  52.3  31.0  11.0  3.7
# ...

# %%
df_2014_seasons_stats['SEASON'] = '2015'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[10]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 482/482 [09:17<00:00,  1.16s/it]
# ['1',
#  'Kevin Durant',
#  'OKC',
#  '25',
#  '81',
#  '58',
#  '23',
#  '38.5',
#  '32.0',
#  '10.5',
#  '20.8',
#  '50.3',
#  '2.4',
#  '6.1',
#  '39.1',
#  '8.7',
#  '9.9',
#  '87.3',
#  '0.7',
#  '6.7',
#  '7.4',
#  '5.5',
#  '3.5',
#  '1.3',
#  '0.7',
#  '2.1',
#  '51.6',
#  '27.0',
#  '3.0',
#  '6.3']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2013_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2013_seasons_stats.head()
# Out:
#                PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA   FG%  3PM  \
# 0  1     Kevin Durant  OKC  25  81  58  23  38.5  32.0  10.5  20.8  50.3  2.4
# 1  2  Carmelo Anthony  NYK  30  77  35  42  38.7  27.4   9.6  21.3  45.2  2.2
# 2  3     LeBron James  MIA  29  77  52  25  37.7  27.1  10.0  17.6  56.7  1.5
# 3  4       Kevin Love  MIN  25  77  39  38  36.3  26.1   8.4  18.5  45.7  2.5
# 4  5     James Harden  HOU  24  73  48  25  38.0  25.4   7.5  16.5  45.6  2.4
#
#    3PA   3P%  FTM  FTA   FT% OREB DREB   REB  AST  TOV  STL  BLK   PF    FP  \
# 0  6.1  39.1  8.7  9.9  87.3  0.7  6.7   7.4  5.5  3.5  1.3  0.7  2.1  51.6
# 1  5.4  40.2  6.0  7.0  84.8  1.9  6.2   8.1  3.1  2.6  1.2  0.7  2.9  45.0
# 2  4.0  37.9  5.7  7.6  75.0  1.1  5.9   6.9  6.3  3.5  1.6  0.3  1.6  47.2
# 3  6.6  37.6  6.8  8.2  82.1  2.9  9.6  12.5  4.4  2.5  0.8  0.5  1.8  48.9
# 4  6.6  36.6  7.9  9.1  86.6  0.8  3.9   4.7  6.1  3.6  1.6  0.4  2.4  42.5
#
#     DD2  TD3  +/-
# 0  27.0  3.0  6.3
# ...

# %%
df_2013_seasons_stats['SEASON'] = '2014'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[11]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tabla.find_elements(By.TAG_NAME, 'tr')]

teams[0]
# Out:
# ['1',
#  'Carmelo Anthony',
#  'NYK',
#  '29',
#  '67',
#  '47',
#  '20',
#  '37.0',
#  '28.7',
#  '10.0',
#  '22.2',
#  '44.9',
#  '2.3',
#  '6.2',
#  '37.9',
#  '6.3',
#  '7.6',
#  '83.0',
#  '2.0',
#  '4.9',
#  '6.9',
#  '2.6',
#  '2.6',
#  '0.8',
#  '0.5',
#  '3.1',
#  '41.9',
#  '10.0',
#  '0.0',
#  '4.6']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2012_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2012_seasons_stats.head()
# Out:
#                PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA   FG%  3PM  \
# 0  1  Carmelo Anthony  NYK  29  67  47  20  37.0  28.7  10.0  22.2  44.9  2.3
# 1  2     Kevin Durant  OKC  24  81  60  21  38.5  28.1   9.0  17.7  51.0  1.7
# 2  3      Kobe Bryant  LAL  34  78  42  36  38.6  27.3   9.5  20.4  46.3  1.7
# 3  4     LeBron James  MIA  28  76  61  15  37.9  26.8  10.1  17.8  56.5  1.4
# 4  5     James Harden  HOU  23  78  43  35  38.3  25.9   7.5  17.1  43.8  2.3
#
#    3PA   3P%  FTM   FTA   FT% OREB DREB  REB  AST  TOV  STL  BLK   PF    FP  \
# 0  6.2  37.9  6.3   7.6  83.0  2.0  4.9  6.9  2.6  2.6  0.8  0.5  3.1  41.9
# 1  4.1  41.6  8.4   9.3  90.5  0.6  7.3  7.9  4.6  3.5  1.4  1.3  1.8  49.3
# 2  5.2  32.4  6.7   8.0  83.9  0.8  4.7  5.6  6.0  3.7  1.4  0.3  2.2  44.4
# 3  3.3  40.6  5.3   7.0  75.3  1.3  6.8  8.0  7.3  3.0  1.7  0.9  1.4  52.1
# 4  6.2  36.8  8.6  10.2  85.1  0.8  4.1  4.9  5.8  3.8  1.8  0.5  2.3  43.7
#
#     DD2  TD3  +/-
# 0  10.0  0.0  4.6
# ...

# %%
df_2012_seasons_stats['SEASON'] = '2013'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[12]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 478/478 [10:56<00:00,  1.37s/it]
# ['1',
#  'Kevin Durant',
#  'OKC',
#  '23',
#  '66',
#  '47',
#  '19',
#  '38.6',
#  '28.0',
#  '9.7',
#  '19.7',
#  '49.6',
#  '2.0',
#  '5.2',
#  '38.7',
#  '6.5',
#  '7.6',
#  '86.0',
#  '0.6',
#  '7.4',
#  '8.0',
#  '3.5',
#  '3.8',
#  '1.3',
#  '1.2',
#  '2.0',
#  '46.6',
#  '18.0',
#  '0.0',
#  '5.6']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2011_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2011_seasons_stats.head()
# Out:
#                  PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA   FG%  \
# 0  1       Kevin Durant  OKC  23  66  47  19  38.6  28.0   9.7  19.7  49.6
# 1  2        Kobe Bryant  LAL  33  58  36  22  38.5  27.9   9.9  23.0  43.0
# 2  3       LeBron James  MIA  27  62  45  17  37.5  27.1  10.0  18.9  53.1
# 3  4         Kevin Love  MIN  23  55  24  31  39.0  26.0   8.6  19.3  44.8
# 4  5  Russell Westbrook  OKC  23  66  47  19  35.3  23.6   8.8  19.2  45.7
#
#    3PM  3PA   3P%  FTM  FTA   FT% OREB DREB   REB  AST  TOV  STL  BLK   PF  \
# 0  2.0  5.2  38.7  6.5  7.6  86.0  0.6  7.4   8.0  3.5  3.8  1.3  1.2  2.0
# 1  1.5  4.9  30.3  6.6  7.8  84.5  1.1  4.3   5.4  4.6  3.5  1.2  0.3  1.8
# 2  0.9  2.4  36.2  6.2  8.1  77.1  1.5  6.4   7.9  6.2  3.4  1.9  0.8  1.5
# 3  1.9  5.1  37.2  6.9  8.4  82.4  4.1  9.2  13.3  2.0  2.3  0.9  0.5  2.8
# 4  0.9  3.0  31.6  5.2  6.3  82.3  1.5  3.1   4.6  5.5  3.6  1.7  0.3  2.2
#
#      FP   DD2  TD3  +/-
# 0  46.6  18.0  0.0  5.6
# ...

# %%
df_2011_seasons_stats['SEASON'] = '2012'

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[1]/div/div/div[1]/label/div/select/option[13]').click()

# %%
driver.find_element(By.XPATH, '//*[@id="__next"]/div[2]/div[2]/div[3]/section[2]/div/div[2]/div[2]/div[1]/div[3]/div/label/div/select/option[1]').click()

# %%
tabla=driver.find_element(By.CLASS_NAME, 'Crom_body__UYOcU')

teams = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
      for f in tqdm(tabla.find_elements(By.TAG_NAME, 'tr'))]

teams[0]
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 452/452 [03:33<00:00,  2.12it/s]
# ['1',
#  'Kevin Durant',
#  'OKC',
#  '22',
#  '78',
#  '52',
#  '26',
#  '38.9',
#  '27.7',
#  '9.1',
#  '19.7',
#  '46.2',
#  '1.9',
#  '5.3',
#  '35.0',
#  '7.6',
#  '8.7',
#  '88.0',
#  '0.7',
#  '6.1',
#  '6.8',
#  '2.7',
#  '2.8',
#  '1.1',
#  '1.0',
#  '2.0',
#  '43.5',
#  '14.0',
#  '0.0',
#  '3.4']

# %%
cabeceras = driver.find_element(By.CLASS_NAME, 'Crom_headers__mzI_m')

cabeceras = [c.text for c in cabeceras.find_elements(By.TAG_NAME, 'th')]

headings = cabeceras[0:30]

# %%
df_2010_seasons_stats = pd.DataFrame(teams, columns = headings)
df_2010_seasons_stats.head()
# Out:
#                PLAYER TEAM AGE  GP   W   L   MIN   PTS  FGM   FGA   FG%  3PM  \
# 0  1     Kevin Durant  OKC  22  78  52  26  38.9  27.7  9.1  19.7  46.2  1.9
# 1  2     LeBron James  MIA  26  79  57  22  38.8  26.7  9.6  18.8  51.0  1.2
# 2  3  Carmelo Anthony  NYK  27  77  43  34  35.7  25.6  8.9  19.5  45.5  1.2
# 3  4      Dwyane Wade  MIA  29  76  54  22  37.1  25.5  9.1  18.2  50.0  0.8
# 4  5      Kobe Bryant  LAL  32  82  57  25  33.9  25.3  9.0  20.0  45.1  1.4
#
#    3PA   3P%  FTM  FTA   FT% OREB DREB  REB  AST  TOV  STL  BLK   PF    FP  \
# 0  5.3  35.0  7.6  8.7  88.0  0.7  6.1  6.8  2.7  2.8  1.1  1.0  2.0  43.5
# 1  3.5  33.0  6.4  8.4  75.9  1.0  6.5  7.5  7.0  3.6  1.6  0.6  2.1  49.2
# 2  3.3  37.8  6.6  7.9  83.8  1.5  5.8  7.3  2.9  2.7  0.9  0.6  2.9  40.4
# 3  2.7  30.6  6.5  8.6  75.8  1.6  4.8  6.4  4.6  3.1  1.5  1.1  2.6  44.7
# 4  4.3  32.3  5.9  7.1  82.8  1.0  4.1  5.1  4.7  3.0  1.2  0.1  2.1  39.7
#
#     DD2  TD3  +/-
# 0  14.0  0.0  3.4
# ...

# %%
df_2010_seasons_stats['SEASON'] = '2011'

# %%
players_stats = pd.concat([df_2021_seasons_stats,df_2020_seasons_stats,df_2019_seasons_stats,df_2018_seasons_stats,df_2017_seasons_stats,df_2016_seasons_stats,df_2015_seasons_stats,df_2014_seasons_stats,df_2013_seasons_stats,df_2012_seasons_stats,df_2011_seasons_stats,df_2010_seasons_stats])
players_stats.reset_index(drop = True, inplace = True)
players_stats.head()
# Out:
#                      PLAYER TEAM AGE  GP   W   L   MIN   PTS   FGM   FGA  \
# 0  1            Joel Embiid  PHI  28  68  45  23  33.8  30.6   9.8  19.6
# 1  2           LeBron James  LAL  37  56  25  31  37.2  30.3  11.4  21.8
# 2  3  Giannis Antetokounmpo  MIL  27  67  45  22  32.9  29.9  10.3  18.6
# 3  4           Kevin Durant  BKN  33  55  36  19  37.2  29.9  10.5  20.3
# 4  5            Luka Doncic  DAL  23  65  44  21  35.4  28.4   9.9  21.6
#
#     FG%  3PM  3PA   3P%  FTM   FTA   FT% OREB DREB   REB  AST  TOV  STL  BLK  \
# 0  49.9  1.4  3.7  37.1  9.6  11.8  81.4  2.1  9.6  11.7  4.2  3.1  1.1  1.5
# 1  52.4  2.9  8.0  35.9  4.5   6.0  75.6  1.1  7.1   8.2  6.2  3.5  1.3  1.1
# 2  55.3  1.1  3.6  29.3  8.3  11.4  72.2  2.0  9.6  11.6  5.8  3.3  1.1  1.4
# 3  51.8  2.1  5.5  38.3  6.8   7.4  91.0  0.5  6.9   7.4  6.4  3.5  0.9  0.9
# 4  45.7  3.1  8.8  35.3  5.6   7.5  74.4  0.9  8.3   9.1  8.7  4.5  1.2  0.6
#
#     PF    FP   DD2   TD3   +/- SEASON
# ...

# %%
players_stats.TEAM.value_counts()
# Out:
# MEM    219
# CLE    218
# WAS    210
# PHI    209
# DAL    209
# LAL    209
# HOU    205
# OKC    205
# NYK    204
# MIL    204
# BOS    202
# ATL    202
# TOR    202
# ORL    201
# UTA    200
# DEN    199
# IND    199
# MIA    199
# LAC    198
# DET    198
# SAS    198
# PHX    197
# SAC    197
# CHA    195
# CHI    194
# MIN    194
# POR    192
# GSW    188
# BKN    180
# NOP    160
# NOH     53
# NJN     39
# Name: TEAM, dtype: int64

# %%
players_stats['TEAM'].replace(['MEM','CLE','WAS','PHI','DAL','LAL','HOU','OKC','NYK','MIL','BOS','ATL','TOR','ORL','UTA','DEN','IND','MIA','LAC','DET','SAS','PHX','SAC','CHA','CHI','MIN','POR','GSW','BKN','NOP','NOH','NJN'],
                              ['Memphis Grizzlies','Cleveland Cavaliers','Washington Wizards','Philadelphia 76ers','Dallas Mavericks','Los Angeles Lakers','Houston Rockets','Oklahoma City Thunder','New York Knicks','Milwaukee Bucks','Boston Celtics','Atlanta Hawks','Toronto Raptors','Orlando Magic','Utah Jazz','Denver Nuggets','Indiana Pacers','Miami Heat','LA Clippers','Detroit Pistons','San Antonio Spurs','Phoenix Suns','Sacramento Kings','Charlotte Hornets','Chicago Bulls','Minnesota Timberwolves','Portland Trail blazers','Golden State Warriors','Brooklyn Nets','New Orleans Pelicans','New Orleans Pelicans','Brooklyn Nets'], inplace = True)

# %%
players_stats.TEAM.value_counts()
# Out:
# Brooklyn Nets             219
# Memphis Grizzlies         219
# Cleveland Cavaliers       218
# New Orleans Pelicans      213
# Washington Wizards        210
# Philadelphia 76ers        209
# Los Angeles Lakers        209
# Dallas Mavericks          209
# Houston Rockets           205
# Oklahoma City Thunder     205
# Milwaukee Bucks           204
# New York Knicks           204
# Atlanta Hawks             202
# Boston Celtics            202
# Toronto Raptors           202
# Orlando Magic             201
# Utah Jazz                 200
# Miami Heat                199
# Denver Nuggets            199
# Indiana Pacers            199
# San Antonio Spurs         198
# Detroit Pistons           198
# LA Clippers               198
# Sacramento Kings          197
# Phoenix Suns              197
# Charlotte Hornets         195
# Minnesota Timberwolves    194
# Chicago Bulls             194
# Portland Trail blazers    192
# Golden State Warriors     188
# Name: TEAM, dtype: int64

# %%
players_stats.columns[0]
# Out:
# ' '

# %%
players_stats.to_csv('./CSV´s/players_stats.csv', index = False)
